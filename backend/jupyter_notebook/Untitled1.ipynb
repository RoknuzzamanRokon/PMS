# %%
from dotenv import load_dotenv
import os

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")

print(DATABASE_URL)
# Out:
# mysql+pymysql://innopms_usr:Bangla%402030@mysql-d5c202a0-o1a3801e8.database.cloud.ovh.net:20184/innopms_db

# %% [markdown]
# ## Check Database Connection.

# %%
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine, text

load_dotenv(".env")

DATABASE_URL = os.getenv("DATABASE_URL")
# print("DATABASE_URL:", DATABASE_URL)

engine = create_engine(DATABASE_URL)

try:
    with engine.connect() as conn:
        result = conn.execute(text("SELECT 1"))
        print("✅ Database connected successfully")
        print(result.fetchone())
except Exception as e:
    print("❌ Connection failed")
    print(e)
# Out:
# ✅ Database connected successfully
# (1,)

# %%
from sqlalchemy import create_engine, text
import os
from dotenv import load_dotenv

load_dotenv()

DATABASE_URL = os.getenv("DATABASE_URL")
engine = create_engine(DATABASE_URL)


with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES"))
    for row in result:
        
        print(row)
# Out:
# ('guests',)
# ('payments',)
# ('properties',)
# ('property_amenities',)
# ('rate_calendar',)
# ('rate_cancellation_policies',)
# ('rate_plans',)
# ('reservations',)
# ('reservations_rooms',)
# ('room_amenities',)
# ('rooms',)
# ('users',)
# ('z_amenities_codes',)
# ('z_availability_status',)
# ('z_meal_plan',)
# ('z_property_type',)

# %%
query = """
SELECT 
    TABLE_NAME,
    COLUMN_NAME,
    DATA_TYPE,
    COLUMN_TYPE,
    IS_NULLABLE,
    COLUMN_KEY
FROM information_schema.COLUMNS
WHERE TABLE_SCHEMA = DATABASE()
ORDER BY TABLE_NAME, ORDINAL_POSITION;
"""

with engine.connect() as conn:
    result = conn.execute(text(query))
    for row in result:
        print(row)
# Out:
# ('guests', 'Id', 'int', 'int', 'NO', 'PRI')
# ('guests', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('guests', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('guests', 'guest_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('guests', 'first_name', 'varchar', 'varchar(100)', 'YES', '')
# ('guests', 'last_name', 'varchar', 'varchar(100)', 'YES', '')
# ('guests', 'email', 'varchar', 'varchar(255)', 'YES', '')
# ('guests', 'phone', 'varchar', 'varchar(50)', 'YES', '')
# ('guests', 'loyalty_status', 'varchar', 'varchar(50)', 'YES', '')
# ('payments', 'Id', 'int', 'int', 'NO', 'PRI')
# ('payments', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('payments', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('payments', 'payment_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('payments', 'booking_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('payments', 'amount', 'decimal', 'decimal(10,2)', 'NO', '')
# ('payments', 'currency', 'varchar', 'varchar(3)', 'YES', '')
# ('payments', 'payment_method', 'varchar', 'varchar(50)', 'YES', '')
# ('payments', 'payment_status', 'varchar', 'varchar(50)', 'YES', '')
# ('payments', 'transaction_ref', 'varchar', 'varchar(255)', 'YES', '')
# ('properties', 'Id', 'int', 'int', 'NO', 'PRI')
# ('properties', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('properties', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('properties', 'property_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('properties', 'name', 'varchar', 'varchar(255)', 'YES', '')
# ('properties', 'name_lang', 'varchar', 'varchar(255)', 'YES', '')
# ('properties', 'property_type', 'varchar', 'varchar(100)', 'YES', 'MUL')
# ('property_amenities', 'Id', 'int', 'int', 'NO', 'PRI')
# ('property_amenities', 'property_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('property_amenities', 'amenity_code', 'varchar', 'varchar(255)', 'NO', 'MUL')
# ('rate_calendar', 'Id', 'int', 'int', 'NO', 'PRI')
# ('rate_calendar', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_calendar', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_calendar', 'rate_id', 'varchar', 'varchar(255)', 'NO', 'MUL')
# ('rate_calendar', 'stay_date', 'date', 'date', 'NO', 'MUL')
# ('rate_calendar', 'currency', 'varchar', 'varchar(3)', 'YES', '')
# ('rate_calendar', 'base_rate', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_calendar', 'tax', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_calendar', 'availability', 'varchar', 'varchar(10)', 'YES', 'MUL')
# ('rate_cancellation_policies', 'Id', 'int', 'int', 'NO', 'PRI')
# ('rate_cancellation_policies', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_cancellation_policies', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_cancellation_policies', 'rate_id', 'varchar', 'varchar(255)', 'NO', 'MUL')
# ('rate_cancellation_policies', 'season_start_date', 'date', 'date', 'YES', '')
# ('rate_cancellation_policies', 'season_end_date', 'date', 'date', 'YES', '')
# ('rate_cancellation_policies', 'days_before_arrival', 'int', 'int', 'NO', '')
# ('rate_cancellation_policies', 'penalty_type', 'varchar', 'varchar(50)', 'YES', '')
# ('rate_cancellation_policies', 'penalty_value', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_cancellation_policies', 'description', 'varchar', 'varchar(255)', 'YES', '')
# ('rate_plans', 'Id', 'int', 'int', 'NO', 'PRI')
# ('rate_plans', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_plans', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('rate_plans', 'rate_id', 'varchar', 'varchar(255)', 'NO', 'UNI')
# ('rate_plans', 'room_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('rate_plans', 'title', 'varchar', 'varchar(255)', 'YES', '')
# ('rate_plans', 'description', 'varchar', 'varchar(255)', 'YES', '')
# ('rate_plans', 'meal_plan', 'varchar', 'varchar(10)', 'YES', 'MUL')
# ('rate_plans', 'is_refundable', 'tinyint', 'tinyint(1)', 'YES', '')
# ('rate_plans', 'bed_type', 'varchar', 'varchar(50)', 'YES', '')
# ('rate_plans', 'cancellation_policy', 'varchar', 'varchar(50)', 'YES', '')
# ('rate_plans', 'status', 'tinyint', 'tinyint(1)', 'YES', '')
# ('rate_plans', 'min_stay', 'int', 'int', 'YES', '')
# ('rate_plans', 'max_stay', 'int', 'int', 'YES', '')
# ('rate_plans', 'currency', 'varchar', 'varchar(255)', 'YES', '')
# ('rate_plans', 'base_rate', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'tax_and_service_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'surcharges', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'mandatory_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'resort_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'mandatory_tax', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'total_inventory', 'int', 'int', 'YES', '')
# ('rate_plans', 'available_inventory', 'int', 'int', 'YES', '')
# ('rate_plans', 'sold_inventory', 'int', 'int', 'YES', '')
# ('rate_plans', 'closed_to_arrival', 'tinyint', 'tinyint(1)', 'YES', '')
# ('rate_plans', 'closed_to_departure', 'tinyint', 'tinyint(1)', 'YES', '')
# ('rate_plans', 'stop_sell', 'tinyint', 'tinyint(1)', 'YES', '')
# ('rate_plans', 'extra_adult_rate', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rate_plans', 'extra_child_rate', 'decimal', 'decimal(10,2)', 'YES', '')
# ('reservations', 'Id', 'int', 'int', 'NO', 'PRI')
# ('reservations', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('reservations', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('reservations', 'booking_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('reservations', 'property_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('reservations', 'guest_id', 'varchar', 'varchar(100)', 'YES', 'MUL')
# ('reservations', 'check_in_date', 'date', 'date', 'NO', 'MUL')
# ('reservations', 'check_out_date', 'date', 'date', 'NO', '')
# ('reservations', 'total_price', 'decimal', 'decimal(10,2)', 'YES', '')
# ('reservations', 'currency', 'varchar', 'varchar(3)', 'YES', '')
# ('reservations', 'booking_status', 'varchar', 'varchar(50)', 'YES', '')
# ('reservations_rooms', 'Id', 'int', 'int', 'NO', 'PRI')
# ('reservations_rooms', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('reservations_rooms', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('reservations_rooms', 'booking_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('reservations_rooms', 'room_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('reservations_rooms', 'rate_id', 'varchar', 'varchar(255)', 'NO', 'MUL')
# ('reservations_rooms', 'room_name', 'varchar', 'varchar(255)', 'YES', '')
# ('reservations_rooms', 'room_name_lang', 'varchar', 'varchar(255)', 'YES', '')
# ('reservations_rooms', 'room_rate_snapshot', 'decimal', 'decimal(10,2)', 'YES', '')
# ('reservations_rooms', 'tax_snapshot', 'decimal', 'decimal(10,2)', 'YES', '')
# ('reservations_rooms', 'occupant_name', 'varchar', 'varchar(255)', 'YES', '')
# ('room_amenities', 'Id', 'int', 'int', 'NO', 'PRI')
# ('room_amenities', 'room_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('room_amenities', 'amenity_code', 'varchar', 'varchar(255)', 'NO', 'MUL')
# ('rooms', 'Id', 'int', 'int', 'NO', 'PRI')
# ('rooms', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('rooms', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('rooms', 'property_id', 'varchar', 'varchar(100)', 'NO', 'MUL')
# ('rooms', 'room_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('rooms', 'room_name', 'varchar', 'varchar(255)', 'YES', '')
# ('rooms', 'room_name_lang', 'varchar', 'varchar(255)', 'YES', '')
# ('rooms', 'base_rate', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rooms', 'tax_and_service_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rooms', 'surcharges', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rooms', 'mandatory_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rooms', 'resort_fee', 'decimal', 'decimal(10,2)', 'YES', '')
# ('rooms', 'mandatory_tax', 'decimal', 'decimal(10,2)', 'YES', '')
# ('users', 'Id', 'int', 'int', 'NO', 'PRI')
# ('users', 'created_at', 'timestamp', 'timestamp', 'YES', '')
# ('users', 'updated_at', 'timestamp', 'timestamp', 'YES', '')
# ('users', 'user_id', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('users', 'username', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('users', 'password_hash', 'varchar', 'varchar(255)', 'NO', '')
# ('users', 'first_name', 'varchar', 'varchar(100)', 'YES', '')
# ('users', 'last_name', 'varchar', 'varchar(100)', 'YES', '')
# ('users', 'role', 'varchar', 'varchar(50)', 'YES', '')
# ('users', 'status', 'tinyint', 'tinyint(1)', 'YES', '')
# ('z_amenities_codes', 'Id', 'int', 'int', 'NO', 'PRI')
# ('z_amenities_codes', 'code', 'varchar', 'varchar(255)', 'NO', 'UNI')
# ('z_amenities_codes', 'name', 'varchar', 'varchar(255)', 'YES', '')
# ('z_amenities_codes', 'for_room', 'tinyint', 'tinyint(1)', 'YES', '')
# ('z_amenities_codes', 'for_property', 'tinyint', 'tinyint(1)', 'YES', '')
# ('z_availability_status', 'Id', 'int', 'int', 'NO', 'PRI')
# ('z_availability_status', 'code', 'varchar', 'varchar(10)', 'NO', 'UNI')
# ('z_availability_status', 'title', 'varchar', 'varchar(255)', 'YES', '')
# ('z_availability_status', 'desc', 'varchar', 'varchar(255)', 'YES', '')
# ('z_meal_plan', 'Id', 'int', 'int', 'NO', 'PRI')
# ('z_meal_plan', 'code', 'varchar', 'varchar(10)', 'NO', 'UNI')
# ('z_meal_plan', 'title', 'varchar', 'varchar(255)', 'YES', '')
# ('z_meal_plan', 'desc', 'varchar', 'varchar(255)', 'YES', '')
# ('z_property_type', 'Id', 'int', 'int', 'NO', 'PRI')
# ('z_property_type', 'code', 'varchar', 'varchar(100)', 'NO', 'UNI')
# ('z_property_type', 'title', 'varchar', 'varchar(255)', 'YES', '')
# ('z_property_type', 'desc', 'varchar', 'varchar(255)', 'YES', '')

# %%
query = """
SELECT 
    *
FROM z_availability_status;
"""

with engine.connect() as conn:
    result = conn.execute(text(query))
    for row in result:
        print(row)
# Out:
# (1, '1', 'AVAILABLE', 'Room is free and can be booked.')
# (2, '2', 'BOOKED', 'Room is already reserved by a guest.')
# (3, '3', 'STOP_SELL', 'Hotel stops selling the room even if inventory exists.')
# (4, '4', 'CTA', 'Guests cannot check-in on that date, but they may stay if they checked in earlier.')
# (5, '5', 'CTD', 'Guests cannot check out on that date.')
# (6, '6', 'OUT_OF_ORDER', 'Room cannot be sold because of maintenance or damage.')
# (7, '7', 'OUT_OF_SERVICE', 'Room is temporarily unavailable but not under major repair.')
# (11, '8', 'OVERBOOKED', 'Hotel sells more rooms than available intentionally.')
